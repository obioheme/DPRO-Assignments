# %%
import matplotlib.pyplot as plt

rice_grain = 1
rice_per_day = []
rice_per_day.append(rice_grain)
for grains in range (2, 101):
    rice_grain *=2
    rice_per_day.append(rice_grain)
print(rice_per_day)
# Out:
# [1, 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096, 8192, 16384, 32768, 65536, 131072, 262144, 524288, 1048576, 2097152, 4194304, 8388608, 16777216, 33554432, 67108864, 134217728, 268435456, 536870912, 1073741824, 2147483648, 4294967296, 8589934592, 17179869184, 34359738368, 68719476736, 137438953472, 274877906944, 549755813888, 1099511627776, 2199023255552, 4398046511104, 8796093022208, 17592186044416, 35184372088832, 70368744177664, 140737488355328, 281474976710656, 562949953421312, 1125899906842624, 2251799813685248, 4503599627370496, 9007199254740992, 18014398509481984, 36028797018963968, 72057594037927936, 144115188075855872, 288230376151711744, 576460752303423488, 1152921504606846976, 2305843009213693952, 4611686018427387904, 9223372036854775808, 18446744073709551616, 36893488147419103232, 73786976294838206464, 147573952589676412928, 295147905179352825856, 590295810358705651712, 1180591620717411303424, 2361183241434822606848, 4722366482869645213696, 9444732965739290427392
# ...

# %%
plt.title("Number of Rice Received")
plt.xlabel("number of Days")
plt.ylabel("Number of Rice")
plt.plot(rice_per_day, color = "m")
plt.show()

# %%
def compute_sorori_shinzaemon(n_days = 100):
    days = n_days;
    list_n_grains = []
    list_total_grains = []
    rice_grains = 1
    total_rice = 1
    list_n_grains.append(rice_grains)
    list_total_grains.append(total_rice)
    
    for day in range(1, days):
        rice_grains *= 2
        total_rice += rice_grains
        list_n_grains.append(rice_grains)
        list_total_grains.append(total_rice)
    #print("List n grains: " + str(list_n_grains))
    #print(len(list_n_grains))
    #print("list total grains: " + str(list_total_grains))
    #print(len(list_total_grains))
    
    pass
    return list_n_grains, list_total_grains

compute_sorori_shinzaemon(n_days = 100)
# Out:
# ([1,
#   2,
#   4,
#   8,
#   16,
#   32,
#   64,
#   128,
#   256,
#   512,
#   1024,
#   2048,
#   4096,
#   8192,
#   16384,
#   32768,
#   65536,
#   131072,
#   262144,
#   524288,
#   1048576,
#   2097152,
#   4194304,
#   8388608,
#   16777216,
#   33554432,
#   67108864,
#   134217728,
#   268435456,
#   536870912,
#   1073741824,
#   2147483648,
#   4294967296,
#   8589934592,
#   17179869184,
#   34359738368,
#   68719476736,
#   137438953472,
#   274877906944,
#   549755813888,
#   1099511627776,
#   2199023255552,
#   4398046511104,
#   8796093022208,
#   17592186044416,
#   35184372088832,
#   70368744177664,
#   140737488355328,
#   281474976710656,
#   562949953421312,
#   1125899906842624,
#   2251799813685248,
#   4503599627370496,
#   9007199254740992,
#   18014398509481984,
#   36028797018963968,
#   72057594037927936,
#   144115188075855872,
#   288230376151711744,
#   576460752303423488,
#   1152921504606846976,
#   2305843009213693952,
#   4611686018427387904,
# ...

# %%
def days_to_live(people = 5):
    num_people = people
    num_rice = list_total_grains[-1]
    
    #According to United Nations, 19,200 grains can feed 1 adult per day
    total_rice_per_day = 19200 * num_people
    num_days_to_live = int(num_rice / total_rice_per_day)
    print(f"{num_people} People can live on {num_rice} grains of rice for {num_days_to_live} days.")
    
days_to_live(people = 1000)
# Out:
# 1000 People can live on 1267650600228229401496703205375 grains of rice for 66023468761886947803136 days.
